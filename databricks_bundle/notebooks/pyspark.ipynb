# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()

employee_data = [
    (1,'John','IT',70000,10,'2021-01-15','Bangalore'),
    (2,'Mary','HR',50000,11,'2020-03-10','Mumbai'),
    (3,'David','IT',80000,10,'2019-07-20','Bangalore'),
    (4,'Sarah','Finance',60000,12,'2022-05-01','Delhi'),
    (5,'Tom','IT',75000,10,'2021-09-15','Chennai'),
    (6,'Alice','HR',55000,11,'2018-12-12','Mumbai'),
    (7,'Bob','Finance',65000,12,'2020-11-01','Delhi'),
    (8,'Emma','IT',85000,10,'2017-06-25','Bangalore'),
    (9,'Mike','Sales',45000,13,'2023-01-10','Pune'),
    (10,'James','IT',100000,None,'2015-01-01','Bangalore'),
    (11,'Nancy','HR',90000,None,'2014-05-01','Mumbai'),
    (12,'Robert','Finance',95000,None,'2013-03-15','Delhi'),
    (13,'Steve','Sales',85000,None,'2016-08-20','Pune')
]

employee_df = spark.createDataFrame(
    employee_data,
    ["EmpID","Name","Department","Salary",
     "ManagerID","JoinDate","City"]
)

employee_df.show()
